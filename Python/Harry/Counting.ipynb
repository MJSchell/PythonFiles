# %% [markdown]
# characters : 5385286
#
# pages : 4703
#
# words that are len()
# 3: 11505
# 5: 21525
# 7: 44317
# 9: 218790
# 11+: 551335
# total: 847472

# %%
import matplotlib.pyplot as plt
y=[5385286,4703,11505,21525,44317,218790,551335]
mylabels=['characters','pages','Len 3','Len 5','Len 7','Len 9','Len 11+']

plt.pie(y[2:],labels = mylabels[2:])

plt.show()

plt.bar(mylabels[2:], y[2:], color ='maroon',
        width = 0.1)
 
plt.xlabel("Whats Graphed")
plt.ylabel("Amount Referenced")
plt.title("Graphing")
plt.show()

plt.pie(y,labels = mylabels)

plt.show()

plt.bar(mylabels, y, color ='maroon',
        width = 0.1)
 
plt.xlabel("Whats Graphed")
plt.ylabel("Amount Referenced")
plt.title("Graphing")
plt.ylim(4000,500000)
plt.show()

# %% [markdown]
# Harry Potter : 23505
# Ron Weasley : 9635
# Albus Dumbledore : 3448
# Hagrid : 2014
# Hermione Granger : 5437
# Draco Malfoy : 1490
# Voldemort: 1237

# %%
Amount=[23505,9635,3448,2014,5437,1490,1237]
mylabels=["Harry","Ron","Dumbledore","Hagrid","Hermione","Malfoy","Voldemort"]

plt.pie(Amount,labels = mylabels)

plt.show()

plt.bar(mylabels, Amount, color ='maroon',
        width = 0.1)
 
plt.xlabel("Whats Graphed")
plt.ylabel("Amount Referenced")
plt.title("Graphing")
plt.show()

# %%
OriginalBookSize=[496,555,708,1234,1676,1103,1275]
WithoutSpacesSize=[486,544,694,1210,1645,1083,1251]
WithoutPageLine=[474,531,676,1207,1605,1057,1226]
together=[496,486,474,555,544,531,708,694,676,1234,1210,1207,1676,1645,1605,1103,1083,1057,1275,1251,1226]
labels=["Book1","NoSpace1","PageNumber1","Book2","NoSpace2","PageNumber2","Book3","NoSpace3","PageNumber3","Book4","NoSpace4","PageNumber4","Book5","NoSpace5","PageNumber5","Book6","NoSpace6","PageNumber6","Book7","NoSpace7","PageNumber7"]
plt.bar(labels[0:3], together[0:3], color ='maroon',
        width = 0.1)
 
plt.xlabel("Whats Graphed")
plt.ylabel("Kb Size")
plt.title("Graphing")
plt.ylim(450)
plt.show()
plt.bar(labels[3:6], together[3:6], color ='maroon',
        width = 0.1)
 
plt.xlabel("Whats Graphed")
plt.ylabel("Kb Size")
plt.title("Graphing")
plt.ylim(525)
plt.show()
plt.bar(labels[6:9], together[6:9], color ='maroon',
        width = 0.1)
 
plt.xlabel("Whats Graphed")
plt.ylabel("Kb Size")
plt.title("Graphing")
plt.ylim(650)
plt.show()
plt.bar(labels[9:12], together[9:12], color ='maroon',
        width = 0.1)
 
plt.xlabel("Whats Graphed")
plt.ylabel("Kb Size")
plt.title("Graphing")
plt.ylim(1200)
plt.show()
plt.bar(labels[12:15], together[12:15], color ='maroon',
        width = 0.1)
 
plt.xlabel("Whats Graphed")
plt.ylabel("Kb Size")
plt.title("Graphing")
plt.ylim(1600)
plt.show()
plt.bar(labels[15:18], together[15:18], color ='maroon',
        width = 0.1)
 
plt.xlabel("Whats Graphed")
plt.ylabel("Kb Size")
plt.title("Graphing")
plt.ylim(1000)
plt.show()
plt.bar(labels[18:21], together[18:21], color ='maroon',
        width = 0.1)
 
plt.xlabel("Whats Graphed")
plt.ylabel("Kb Size")
plt.ylim(1200)
plt.title("Graphing")
plt.show()
